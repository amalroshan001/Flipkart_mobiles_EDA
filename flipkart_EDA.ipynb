# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv("Flipkart_Mobiles.csv")
df
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
df.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5          11990
#
#    Original Price
# 0           15990
# 1           15990
# 2           17990
# 3           17990
# 4           15990

# %%
df.tail()
# Out:
#         Brand   Model          Color Memory Storage  Rating  Selling Price  \
# 3109  SAMSUNG  M52 5G  Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G       Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G       Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G    Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G       Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 3109           25990
# 3110           28449
# 3111           31489
# 3112           22989
# 3113           22595

# %%
df.shape
# Out:
# (3114, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           3114 non-null   object
#  1   Model           3114 non-null   object
#  2   Color           3114 non-null   object
#  3   Memory          3071 non-null   object
#  4   Storage         3075 non-null   object
#  5   Rating          2970 non-null   float64
#  6   Selling Price   3114 non-null   int64
#  7   Original Price  3114 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 194.8+ KB

# %%
# distribution of data
df.describe().T
# Out:
#                  count          mean           std     min       25%      50%  \
# Rating          2970.0      4.243098      0.271991     2.3      4.10      4.3
# Selling Price   3114.0  26436.625562  30066.892622  1000.0   9990.00  15000.0
# Original Price  3114.0  28333.473025  31525.599889  1000.0  10030.25  16889.5
#
#                     75%       max
# Rating              4.4       5.0
# Selling Price   28999.0  179900.0
# Original Price  31500.0  189999.0

# %%
# fillna values
df2.fillna(0)
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
df3=df2.copy()

# %%
# distribution of data
df2.keys()
# Out:
# Index(['Brand', 'Model', 'Color', 'Memory', 'Storage', 'Rating',
#        'Selling Price', 'Original Price'],
#       dtype='object')

# %%
df2=df.copy()

# %%
df.dtypes
# Out:
# Brand              object
# Model              object
# Color              object
# Memory             object
# Storage            object
# Rating            float64
# Selling Price       int64
# Original Price      int64
# dtype: object

# %%
# checking number of null values
df2.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             43
# Storage            39
# Rating            144
# Selling Price       0
# Original Price      0
# dtype: int64

# %% [markdown]
# Memory has 43 and rating has 144 null values

# %%
df2.nunique()
# Out:
# Brand              17
# Model             914
# Color             639
# Memory             26
# Storage            26
# Rating             25
# Selling Price     844
# Original Price    819
# dtype: int64

# %% [markdown]
# - Number of unique values in each features

# %%
df2.duplicated().sum()
# Out:
# 108

# %% [markdown]
# - There are 108 duplicated values in this data

# %% [markdown]
# ### Exploring Dataset

# %%
#visualize missing numbers in the dataset
msno.bar(df2,figsize=(6,3),color='pink')
# Out:
# <Axes: >

# %% [markdown]
# Visualisation of missing values in the dataset

# %%
df2['Brand'].groupby(df2['Brand']).count().sort_values(ascending=False)
# Out:
# Brand
# SAMSUNG         719
# Apple           387
# realme          327
# OPPO            260
# Nokia           213
# Xiaomi          198
# Infinix         151
# GIONEE          129
# vivo            124
# Lenovo          121
# ASUS            118
# Motorola        105
# LG               99
# POCO             74
# HTC              55
# Google Pixel     29
# IQOO              5
# Name: Brand, dtype: int64

# %% [markdown]
# - Most purchased brand is SAMSUNG which has 719 count
# - Least Purchased brand is IQOO which has only 5 count

# %%
df2['Brand'].groupby(df2['Memory']).count().sort_values(ascending=False)
# Out:
# Memory
# 4 GB      750
# 3 GB      498
# 6 GB      497
# 2 GB      390
# 8 GB      345
# 1 GB      193
# 4GB       137
# 12 GB      63
# 512 MB     46
# 4 MB       39
# 1.5 GB     29
# 16 MB      16
# 64 MB      15
# 32 MB      14
# 8 MB       14
# 768 MB      6
# 128 MB      4
# 10 MB       3
# 2 MB        2
# 18 GB       2
# 46 MB       2
# 16 GB       2
# 32 GB       1
# 153 MB      1
# 100 MB      1
# 30 MB       1
# Name: Brand, dtype: int64

# %% [markdown]
# Most purchased memory has 4gb

# %%
sns.set_style('white')

# %%
sns.pairplot(df2, hue='Brand')
# Out:
# C:\Users\sachu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# selling price v/s rating and original price v/s rating looks same but a small variation

# %%
sns.displot(df2, x='Selling Price',bins=[5000,10000,15000,20000,25000,30000,35000,40000,50000,60000,80000], aspect=1.2,color='#fd6c9e')
# Out:
# C:\Users\sachu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df2, x='Original Price',bins=[5000,10000,15000,20000,25000,30000,35000,40000,50000,60000,80000], aspect=1.2,color='#ff8243')
# Out:
# C:\Users\sachu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# It is quite clear that the market is saturated with lower to mid range cost phones i.e. <25000 INR

# %%
#brandwise mobile phone price segments
sns.displot(df2, x='Selling Price',bins=5, hue='Brand',aspect=1.2)
# Out:
# C:\Users\sachu\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax=sns.countplot(x="Brand", data=df)

# %% [markdown]
# This shows the most saled mobile which is clearly SAMSUNG

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax = sns.stripplot(y="Rating", x="Brand", data=df)

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax = sns.stripplot(y="Selling Price", x="Brand", data=df2)

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax = sns.stripplot(y="Original Price", x="Brand", data=df2)

# %%
# To check the outliers
fig, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(x="Brand", y="Selling Price", data=df)

# %%
# Brandwise Mean Selling prices
round(df2.groupby('Brand')['Selling Price'].mean(),0).sort_values(ascending=False)
# Out:
# Brand
# Apple           81986.0
# Google Pixel    61392.0
# IQOO            37190.0
# HTC             28314.0
# SAMSUNG         24296.0
# vivo            23866.0
# ASUS            20327.0
# LG              19323.0
# OPPO            18560.0
# Xiaomi          16942.0
# POCO            16871.0
# realme          16397.0
# Motorola        16357.0
# Infinix         11092.0
# Lenovo          10084.0
# Nokia            9429.0
# GIONEE           7135.0
# Name: Selling Price, dtype: float64

# %%
corr_matrix = df2.corr(numeric_only=True)
corr_matrix
# Out:
#                   Rating  Selling Price  Original Price
# Rating          1.000000       0.458545        0.451354
# Selling Price   0.458545       1.000000        0.986097
# Original Price  0.451354       0.986097        1.000000

# %%
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
df2['Discount Percentage'] = ((df2['Original Price'] - df2['Selling Price']) / df2['Original Price']) * 100
df2[df2['Discount Percentage']==df2['Discount Percentage'].max()]
# Out:
#       Brand        Model  Color  Memory Storage  Rating  Selling Price  \
# 803  GIONEE  Pioneer P3   White  512 MB    4 GB     3.6           2350
#
#      Original Price  Discount Percentage
# 803            7996            70.610305

# %% [markdown]
# GIONEE is the most discounted brand in this dataset

# %% [markdown]
# ### Rating v/s Selling Price

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Rating', y='Selling Price', data=df,hue="Brand")
plt.show()

# %% [markdown]
# 3.5 to 4.5 has the most rating and selling price is most commonly 10000 to 60000

# %% [markdown]
# ### top 10 most rated models

# %%
top10_models = df.nlargest(10,"Rating")
top10_models
# Out:
#         Brand           Model           Color  Memory Storage  Rating  \
# 1252    Apple  iPhone 7 Plus              Red    3 GB  256 GB     5.0
# 1348    Apple  iPhone 7 Plus              Red    3 GB  256 GB     5.0
# 2021  SAMSUNG  SM-B310EZDDINS           Black  100 MB  100 MB     5.0
# 2789     vivo         X60 Pro    Shimmer Blue   12 GB  256 GB     5.0
# 2791     vivo           X50        Frost Blue    8 GB  256 GB     5.0
# 2797     vivo             Z1x  Phantom Purple    6 GB   64 GB     5.0
# 2799     vivo              S2   Diamond Black    4 GB  128 GB     5.0
# 2771     vivo            Y33T    Mirror Black    8 GB  128 GB     4.9
# 3061   realme            9 5G    Meteor Black    6 GB  128 GB     4.8
# 3062   realme            9 5G  Stargaze White    6 GB  128 GB     4.8
#
#       Selling Price  Original Price
# 1252          85400           85400
# 1348          85400           85400
# 2021           1949            1949
# 2789          48780           48780
# ...
